# %% [markdown]
# #### Similarity visualization against informative tiles vs all tiles with a slide

# %%
import h5py
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import cv2
from sklearn.metrics.pairwise import cosine_similarity
Image.MAX_IMAGE_PIXELS = None  
# ---------- CONFIG ----------

  # Color map for similarity
def visualization_bg_filtered(slide, base_image_path, features_h5_path, important_h5_path, output_image_path, tile_size=224, alpha=0.5):
    colormap = plt.cm.jet
# ---------- 1. LOAD BASE IMAGE ----------
    base_img = Image.open(base_image_path).convert("RGBA")
    base_np = np.array(base_img)  # Convert to NumPy for easy manipulation
    
    # ---------- 2. LOAD COORDS & FEATURES ----------
    with h5py.File(feature_h5_path, "r") as f:
        coords = np.array(f["coords"])
        features = np.array(f["feats"])
    
    with h5py.File(important_h5_path, "r") as f:
        important_coords = np.array(f[slide])[:3]  # Most important tile
    
    # Find index of important tile
    important_indices = []
    for coord in important_coords:
        idx = np.where((coords == coord).all(axis=1))[0]
        if len(idx) > 0:
            important_indices.append(idx[0])
    important_features = features[important_indices]
    print(slide)
    # ---------- 3. SIMILARITY CALCULATION ----------
    similarities = cosine_similarity(features, important_features)
    # Normalize [0, 1]
    summed_sim = similarities.sum(axis=1)
    similarities_norm = (summed_sim/3)
    # ---------- 4. APPLY COLOR OVERLAY ----------
    overlay_np = base_np.copy()  # Start with original image
    
    for idx, (x, y) in enumerate(coords):
        sim_val = similarities_norm[idx]
        
        # Extract region from base image
        region = base_np[int(y/2):int(y/2)+tile_size, int(x/2):int(x/2)+tile_size].copy()
        if region.shape[0] < tile_size or region.shape[1] < tile_size:
            continue  # Skip tiles that go out of bounds
    
        # Create tissue mask (ignore white areas)
        gray = region[:, :, :1]
        _, tissue_mask = cv2.threshold(gray, 220, 255, cv2.THRESH_BINARY_INV)  # Tissue = dark
        tissue_mask = tissue_mask.astype(bool)
    
        # Get overlay color from colormap
        color = np.array(colormap(sim_val)) * 255  # RGBA
        color = color[:3]  # Take RGB only
        # Apply overlay only on tissue
         
        if sim_val>0.7:
            region_rgb = region[..., :3]
            region_rgb[tissue_mask] = ((1 - alpha) * region_rgb[tissue_mask] + alpha * np.array([255, 0, 0])).astype(np.uint8)
            region[..., :3] = region_rgb
            # Put region back into overlay image
            overlay_np[int(y/2):int(y/2)+tile_size, int(x/2):int(x/2)+tile_size] = region
    
    # ---------- 5. SAVE OUTPUT ----------
    overlay_img = Image.fromarray(overlay_np)
    overlay_img = overlay_img.convert('RGB')
    draw = ImageDraw.Draw(overlay_img)
    for (x,y) in important_coords:
        box = [x/2, y/2, x/2 + tile_size , y/2 + tile_size]
        draw.rectangle(box, outline="black", width=12)  
    overlay_img.save(output_image_path, format="jpeg")  # PNG for quality & transparency

# ---------- 6. DISPLAY LOW-RES INLINE ----------
#low_res = overlay_img.resize((overlay_img.width // 4, overlay_img.height // 4))
#plt.imshow(low_res)
#plt.axis("off")
#plt.show()

# %%
 # Base WSI (or downsampled version)
# the paths are left empty to push to github since the data is private
from tqdm import tqdm
important_h5_path = " " # h5 files with important tiles for all the images [image_id: [important tiles]]
targets = # A list of all the slide names
for slide in targets: 
    base_image_path = ""
    feature_h5_path = ""
    output_image_path = ""
    visualization_bg_filtered(slide, base_image_path, feature_h5_path, important_h5_path, output_image_path, tile_size = 224, alpha = 0.5)
# BT9-103208-00-R00_194046
# BT9-103209-00-R00_194302
# BT9-103210-00-R00_194405
# BT9-103211-00-R00_194508
# BT9-103212-00-R00_194636
# BT9-103213-00-R00_194853
# BT9-103215-00-R00_195312
# BT9-103216-00-R00_195404
# BT9-103220-00-R00_195939
# BT9-103221-00-R00_200028
# BT9-103222-00-R00_200145
# BT9-103223-00-R00_200345
# BT9-103224-00-R00_200506
# BT9-103225-00-R00_200617
# BT9-103226-00-R00_200754
# BT9-103227-00-R00_200854
# BT9-103228-00-R00_201005
# BT9-103229-00-R00_201120
# BT9-103230-00-R00_201210
# BT9-103231-00-R00_201342
# BT9-103232-00-R00_201453
# BT9-103234-00-R00_201911
# BT9-103235-00-R00_202033
# BT9-103236-00-R00_202312
# BT9-103238-00-R00_202556
# BT9-103244-00-R00_203613
# BT9-103247-00-R00_204145
# BT9-103248-00-R00_204241
# BT9-103249-00-R00_204349
# BT9-103250-00-R00_204558
# BT9-103251-00-R00_204740
# BT9-103253-00-R00_205053
# BT9-103254-00-R00_205312
# BT9-103255-00-R00_205527
# BT9-103256-00-R00_205646
# BT9-103257-00-R00_205843
# BT9-103258-00-R00_210112
# BT9-103259-00-R00_210235
# BT9-103260-00-R00_210445
# BT9-103261-00-R00_210526
# BT9-103262-00-R00_210734
# BT9-103263-00-R00_210840
# BT9-103264-00-R00_211101
# BT9-103265-00-R00_211213
# BT9-103267-00-R00_211411
# BT9-103268-00-R00_211615
# BT9-103270-00-R00_211928
# BT9-103271-00-R00_212132
# BT9-103272-00-R00_212410
# BT9-103273-00-R00_212511
# BT9-103274-00-R00_212734
# BT9-103276-00-R00_213113
# BT9-103279-00-R00_213543
# BT9-103280-00-R00_213705
# BT9-103281-00-R00_213749
# BT9-103286-00-R00_214636
# BT9-103288-00-R00_214948
# BT9-103292-00-R00_215623
# BT9-103293-00-R00_215800
# BT9-103294-00-R00_220128
# BT9-103297-00-R00_220812
# BT9-103299-00-R00_221125
# BT9-103300-00-R00_221313
# BT9-103301-00-R00_221450
# BT9-103303-00-R00_090415
# BT9-103305-00-R00_090632
# BT9-103306-00-R00_090820
# BT9-103308-00-R00_091149
# BT9-103309-00-R00_091242
# BT9-103313-00-R00_091655
# BT9-103314-00-R00_091741
# BT9-103315-00-R00_091951
# BT9-103316-00-R00_092231
# BT9-103322-00-R00_093336
# BT9-103323-00-R00_093944
# BT9-103326-00-R00_094557
# BT9-103327-00-R00_094733
# BT9-103328-00-R00_094824
# BT9-103330-00-R00_095111
# BT9-103331-00-R00_095318
# BT9-103332-00-R00_095526
# BT9-103333-00-R00_095621
# BT9-103334-00-R00_095806
# BT9-104433-00-R00_104306

# %% [markdown]
# #### similarity visualization across slides

# %%
def visualization_across_slides_no_bg(features_dir, target_slide, important_coords_path, reference_slides, base_images_dir, output_dir, tile_size=224, alpha =0.5) :
# ----------------------------
    # STEP 2: LOAD TARGET SLIDE FEATURES & COORDS
    # ----------------------------
    target_h5_path = os.path.join(features_dir, f"{target_slide}.h5")
    with h5py.File(target_h5_path, "r") as f:
        target_coords = np.array(f["coords"])       # shape: (num_tiles, 2)
        target_features = np.array(f["feats"])   # shape: (num_tiles, feature_dim)
    
    # ----------------------------
    # STEP 3: LOAD IMPORTANT TILE COORDS FOR ALL REFERENCES
    # ----------------------------
    with h5py.File(important_coords_path, "r") as f:
        important_tiles_dict = {slide: np.array(f[slide]) for slide in reference_slides+[target_slide]}
    
    # ----------------------------
    # STEP 4: AGGREGATE SIMILARITY ACROSS 50 REFERENCES
    # ----------------------------
    # Initialize similarity sum
    summed_sim = np.zeros(len(target_coords))
    
    for ref_slide in reference_slides:
        ref_h5_path = os.path.join(features_dir, f"{ref_slide}.h5")
        with h5py.File(ref_h5_path, "r") as ref_f:
            ref_coords = np.array(ref_f["coords"])
            ref_features = np.array(ref_f["feats"])
    
        # Get top-3 important coords for this reference slide
        top_coords = important_tiles_dict[ref_slide][:3]
    
        # Find their indices
        important_indices = []
        for coord in top_coords:
            idx = np.where((ref_coords == coord).all(axis=1))[0]
            if len(idx) > 0:
                important_indices.append(idx[0])
    
        if len(important_indices) == 0:
            continue  # skip if no matches found
    
        # Extract their features
        ref_important_feats = ref_features[important_indices]
    
        # Compute similarity and sum
        sim_matrix = cosine_similarity(target_features, ref_important_feats)  # shape: (num_target_tiles, 3)
        summed_sim += sim_matrix.sum(axis=1)  # sum across 3 tiles
    
    # Average over references
    avg_sim = summed_sim / len(reference_slides)
    
    # Normalize to [0, 1]
    avg_sim = (avg_sim/3)
    
    # ----------------------------
    # STEP 5: LOAD BASE IMAGE
    # ----------------------------
    base_image_path = base_images_dir
    base_img = Image.open(base_image_path).convert("RGBA")
    overlay = Image.new("RGBA", base_img.size, (0, 0, 0, 0))
    draw = ImageDraw.Draw(overlay)
    
    # ----------------------------
    # STEP 6: CREATE TISSUE MASK
    # ----------------------------
    base_cv = cv2.cvtColor(np.array(base_img), cv2.COLOR_RGBA2RGB)
    gray = base_cv[:,:,0]
    #gray = cv2.cvtColor(base_cv, cv2.COLOR_RGB2GRAY)
    _, tissue_mask = cv2.threshold(gray, 220, 255, cv2.THRESH_BINARY_INV)  # tissue = 1, bg = 0
    
    # ----------------------------
    # STEP 7: APPLY HEATMAP ON TISSUE REGIONS ONLY
    # ----------------------------
    for i, (x, y) in enumerate(target_coords):
        if avg_sim[i]>0.6:
            color = (0, 255, 0, int(255 * alpha))
    
            x1, y1 = int(x/2), int(y/2)
            x2, y2 = x1 + tile_size, y1 + tile_size
    
        # Apply color only to tissue pixels
            for yy in range(y1, y2):
                for xx in range(x1, x2):
                    if yy < base_img.height and xx < base_img.width:
                        if tissue_mask[yy, xx] > 0:
                            overlay.putpixel((xx, yy), color)
    
    # ----------------------------
    # STEP 8: SAVE RESULT
    # ----------------------------
    result = Image.alpha_composite(base_img, overlay)
    result1 = result.convert('RGB')
    draw = ImageDraw.Draw(result1)
    for (x,y) in important_tiles_dict[target_slide][:3]:
        box = [x/2, y/2, x/2 + tile_size , y/2 + tile_size]
        draw.rectangle(box, outline="black", width=12) 
        
    os.makedirs(output_dir, exist_ok=True)
    
    output_path = os.path.join(output_dir, f"{target_slide}.jpg")
    result1.save(output_path, format="jpeg")
    print(f"Visualization saved at {output_path}")

# %%
import h5py
import numpy as np
import random
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image, ImageDraw
import cv2
import os

# ----------------------------
# CONFIGURATION
# ----------------------------
class_of_interest = 0
num_refs = 50
slide_dict = labels.copy()
# Target slide for visualization


# ----------------------------
# STEP 1: SELECT 50 RANDOM REFERENCE SLIDES
# ----------------------------
reference_slides = [s for s, cls in slide_dict.items() if cls == class_of_interest]
reference_slides = random.sample(reference_slides, min(len(reference_slides), num_refs))
print(f"Selected {len(reference_slides)} reference slides for comparison.")

target_slides = [s for s in slides if s not in reference_slides]
for target_slide in target_slides:
    features_dir = ""
    important_coords_path = ""
    base_images_dir = f""
    if slide_dict[target_slide]==0:
        output_dir = f"{class_of_interest}comparison/class_0/"
    else:
        output_dir = f"/{class_of_interest}comparison/class_1/" 
    visualization_across_slides_no_bg(features_dir, target_slide, important_coords_path, reference_slides, base_images_dir, output_dir, tile_size=224, alpha =0.5)
# Out:
# Selected 50 reference slides for comparison.
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102937-00-R00_105005.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102938-00-R00_105057.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102940-00-R00_105446.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102942-00-R00_105811.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102943-00-R00_105902.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102944-00-R00_110106.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102946-00-R00_110412.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102947-00-R00_110545.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102949-00-R00_110917.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102950-00-R00_111100.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102951-00-R00_111310.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102953-00-R00_111642.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102956-00-R00_112336.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102957-00-R00_112620.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102958-00-R00_112828.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102959-00-R00_113003.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102963-00-R00_113639.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102964-00-R00_113757.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102965-00-R00_114341.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102966-00-R00_114553.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102969-00-R00_115038.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102975-00-R00_120135.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102976-00-R00_120359.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102978-00-R00_120727.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102979-00-R00_120941.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102981-00-R00_121456.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102982-00-R00_121742.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102985-00-R00_122358.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102986-00-R00_122612.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102987-00-R00_122815.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102988-00-R00_123041.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102989-00-R00_123253.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102990-00-R00_123456.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102991-00-R00_123719.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102993-00-R00_124146.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102994-00-R00_124414.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102995-00-R00_124737.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-102996-00-R00_125016.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102997-00-R00_125234.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-102998-00-R00_125411.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103000-00-R00_125720.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103001-00-R00_125946.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103003-00-R00_130436.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103006-00-R00_130956.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103007-00-R00_131120.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103010-00-R00_131702.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103012-00-R00_131920.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103013-00-R00_132119.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103014-00-R00_132405.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103016-00-R00_132728.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103017-00-R00_132934.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103020-00-R00_133347.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103023-00-R00_133958.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103024-00-R00_134058.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103025-00-R00_134348.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103028-00-R00_134735.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103031-00-R00_135302.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103034-00-R00_135912.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103037-00-R00_140447.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103038-00-R00_140637.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103039-00-R00_140830.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103040-00-R00_140954.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103041-00-R00_141225.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103042-00-R00_141401.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103046-00-R00_142102.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103047-00-R00_142323.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103048-00-R00_142533.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103050-00-R00_143028.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103051-00-R00_143306.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103053-00-R00_143800.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103054-00-R00_143943.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103055-00-R00_144203.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103058-00-R00_144834.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103059-00-R00_145057.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103060-00-R00_145302.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103062-00-R00_150208.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103063-00-R00_150422.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103064-00-R00_150633.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103066-00-R00_150946.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103067-00-R00_151136.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103069-00-R00_151431.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103070-00-R00_151621.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103071-00-R00_151819.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103075-00-R00_152455.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103077-00-R00_152907.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103079-00-R00_153305.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103080-00-R00_153451.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103081-00-R00_153633.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103082-00-R00_153758.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103085-00-R00_154503.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103086-00-R00_154703.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103087-00-R00_154922.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103090-00-R00_155530.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103091-00-R00_155813.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103092-00-R00_155950.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103093-00-R00_160211.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103094-00-R00_160340.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103095-00-R00_160517.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103096-00-R00_160740.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103097-00-R00_161018.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103100-00-R00_161638.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103101-00-R00_161815.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103102-00-R00_162039.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103103-00-R00_162312.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103104-00-R00_162534.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-103105-00-R00_162736.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_0/BT9-103108-00-R00_163449.jpg
# Visualization saved at /home/mxn477/m07/eagle/intrepretive_visualizations/background_filtered/0comparison/class_1/BT9-